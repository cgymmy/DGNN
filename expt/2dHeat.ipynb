# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
from triangle_gauss import *
from math import pi
import numpy as np
import scipy
import time
import os
from triangle import triangulate
from scipy.interpolate import griddata
from matplotlib.path import Path
from torch.utils.tensorboard import SummaryWriter
import matplotlib.cm as cm
import matplotlib.colors as mcolors
from utilities import *
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
class Heat2d_dg:
    def __init__(self, 
                 boundary_type: str = 'regular', 
                 Nint_elt: int=10, 
                 Nint_edge: int = 20,
                 N_t: int = 10,
                 order: int=2, 
                 partition: float=0.2) -> None:
        self.name = f'DG_2dHeat_{boundary_type}_{Nint_elt}_{Nint_edge}_{order}_{partition}'
        self.genmesh = GenMesh2D(boundary_type=boundary_type, Nint_edge=Nint_edge, Nint_elt=Nint_elt, param=f'pq30a{partition}e')
        self.torch_type = torch.float64
        #
        self.Nelt = self.genmesh.Nelt
        self.Nt = N_t
        self.time = torch.linspace(0, 1.0, N_t  + 1).to(device)
        #
        self.test_func = TestFunction2D()
        self.elt_int, self.elt_weights, self.edges_int, self.mesh_edges_w, self.mesh_normvec, self.xMesh, self.ref_Mesh, self.inv_matrix = self.genmesh.get_mesh()
        self.Mesh = torch.cat((self.xMesh[:, None, ...].expand(-1, N_t + 1, -1, -1), 
                               self.time[None, :, None, None].expand(self.xMesh.shape[0], -1, self.xMesh.shape[1], -1)), dim=-1)
        self.num_eltinnerp = self.genmesh.num_eltp
        self.num_eltbdp = self.genmesh.num_edgep
        # case 1
        if boundary_type == 'regular':
            self.func_f = lambda x, y, t: pi*(-torch.sin(pi*t) + 8*pi*torch.cos(pi*t))*torch.sin(2*pi*x)*torch.sin(2*pi*y)
            # self.func_f = lambda x, y: torch.zeros_like(x)
            self.func_init_u = lambda mesh: torch.sin(2 * pi * mesh[..., [0]]) * torch.sin(2 * pi * mesh[..., [1]])
            self.exact_u = lambda x, y, t: torch.sin(2*pi*x)*torch.sin(2*pi*y) * torch.cos(pi*t)
        else:
            return NotImplementedError
            
        # [degree, points_elt], [degree, 3, points_bd], [degree, elements, points_elt, 2]
        self.v_elt_inner, self.v_elt_bd, self.dv_elt_inner = self.get_test(order=order)
        #
        self.f = self.func_f(self.Mesh[..., [0]], self.Mesh[..., [1]], self.Mesh[..., [2]])
        self.f_inner = self.f[:, :, :self.num_eltinnerp, :]
        self.init_u = self.func_init_u(self.Mesh[:, 0, :, :2])
        #
        self.model = DGNet(num_modules=self.Nelt, input_size=3, hidden_size=50, output_size=1, num_layers=2, act='tanh').to(device).to(self.torch_type)
        # self.model_p = DGNet(num_modules=self.Nelt, input_size=3, hidden_size=50, 
        #                      output_size=2, num_layers=2, act='tanh').to(device).to(self.torch_type)
        #
        self.Lfbgs = torch.optim.LBFGS(self.model.parameters(), lr=1.0, max_iter=50000, 
                                           max_eval=50000, history_size=50, tolerance_grad=1e-7, 
                                           tolerance_change=1.0 * np.finfo(float).eps, 
                                           line_search_fn='strong_wolfe'); self.lfbgsiter = 0
        self.Adam = torch.optim.Adam(self.model.parameters(), lr=1e-4); self.maxiter = 10000; self.adamiter = 0
    
    def get_test(self, order: int=2):
        v, dv = self.test_func.Poly(mesh=self.ref_Mesh, order=order)
        v_elt_inner, v_elt_bd = v[:, :self.num_eltinnerp], v[:, self.num_eltinnerp:].reshape(-1, 3, self.num_eltbdp)
        dv_elt_inner = dv[:, :self.num_eltinnerp, :]
        dv_elt_inner = torch.matmul(self.inv_matrix[None, :, None, :, :], dv_elt_inner[:, None, :, :].unsqueeze(-1)).squeeze(-1)
        return v_elt_inner, v_elt_bd, dv_elt_inner

    
    def loss(self):
        #
        Mesh = self.Mesh.clone().detach().requires_grad_(True).to(device)
        # print(Mesh[:,0,:,2])
        u = self.model(Mesh)
        du = torch.autograd.grad(u, Mesh, grad_outputs=torch.ones_like(u), create_graph=True)[0]

        u_bd = u[..., self.num_eltinnerp:, :].reshape(self.Nelt, self.Nt + 1, 3, self.num_eltbdp)
        du_inner = du[..., :self.num_eltinnerp, :2] # [Elements, Time, Points_elt, 2]
        ut_inner = du[..., :self.num_eltinnerp, 2:3]   # [Elements, Time, Points_elt, 1]
        du_bd = du[..., self.num_eltinnerp:, :2].reshape(self.Nelt, self.Nt + 1, 3, self.num_eltbdp, 2) # [Elements, Time, 3, Points_bd, 2]
        
        # compute local loss
        weak_u = (((ut_inner - self.f_inner)[None, ..., 0] * self.v_elt_inner[:, None, None, :] 
                   + (du_inner[None, ...] * self.dv_elt_inner[:, :, None, ...]).sum(dim=-1)) * self.elt_weights[None, :, None, :]).sum(dim=-1) 
        weak_u =  weak_u - (((du_bd * self.mesh_normvec[:, None, :, None, :]).sum(dim=-1))[None, ...] * self.v_elt_bd[:, None, None, :, :] * self.mesh_edges_w[None, :, None, ...]).sum(dim=(-2, -1))

        # weak_u = torch.topk(weak_u, k=int(0.5*self.Nt), dim=-1)[0]
        # weak_u = torch.topk(weak_u, k=int(0.5*self.Nelt), dim=1)[0]

        local_loss = torch.sum(weak_u**2)
        # print(local_loss)
        # flux loss
        delt_u = u_bd[self.genmesh.inner_label[:, 0, 0], :, self.genmesh.inner_label[:, 0, 1], :] - torch.flip(u_bd[self.genmesh.inner_label[:, 1, 0], :, self.genmesh.inner_label[:, 1, 1], :], dims=[-1])   
        delt_du = du_bd[self.genmesh.inner_label[:, 0, 0], :, self.genmesh.inner_label[:, 0, 1], :, :] - torch.flip(du_bd[self.genmesh.inner_label[:, 1, 0], :, self.genmesh.inner_label[:, 1, 1], :, :], dims=[-2])
        
        flux_loss = torch.sum(delt_u**2) + torch.sum(delt_du**2)
        # print(flux_loss)
        # init loss
        init_loss = torch.sum((u[:, 0, :, 0] - self.init_u[..., 0])**2)
        # print(init_loss)
        # boundary loss
        bd_loss = torch.sum(u_bd[self.genmesh.bd_label[:, 0, 0], :, self.genmesh.bd_label[:, 0, 1], :] ** 2) 
        # print('pass')
        # print(local_loss.item(), flux_loss.item(), bd_loss.item(), init_loss.item())
        loss = 10 * local_loss + flux_loss + bd_loss + init_loss
        return loss
        # mse = torch.mean((u - self.u_exact)**2)
        # mae = torch.max(torch.abs(u - self.u_exact))
        # return loss, mse, mae
    
    def loss_lfbgs(self):
        self.Lfbgs.zero_grad()
        # loss, mse, mae = self.loss()
        loss = self.loss()
        # self.writer.add_scalar(f"mse_vs_iter", mse, self.lfbgsiter + self.adamiter)
        # self.writer.add_scalar(f"mse_vs_time", mse, time.time() - self.t)
        loss.backward()
        self.lfbgsiter += 1
        if self.lfbgsiter % 100 == 0:
            # print(f"LBFGS At iter: {self.lfbgsiter}, loss_train:{loss.item():.6f}, mse:{mse.item():.6f}, mae:{mae.item():.6f}")
            print(f"LBFGS At iter: {self.lfbgsiter}, loss_train:{loss.item():.6f}")
        return loss
    
    def loss_adam(self):
        self.Adam.zero_grad()
        # loss, mse, mae = self.loss()
        loss = self.loss()
        # self.writer.add_scalar(f"mse_vs_iter", mse, self.lfbgsiter + self.adamiter)
        # self.writer.add_scalar(f"mse_vs_time", mse, time.time() - self.t)
        self.adamiter += 1
        if self.adamiter % 100 == 0:
            # print(f"Adam At iter: {self.adamiter}, loss_train:{loss.item():.6f}, mse:{mse.item():.6f}, mae:{mae.item():.6f}")
            print(f"Adam At iter: {self.adamiter}, loss_train:{loss.item():.6f}")
        return loss
    def train(self):
        print('*********** Started training ...... ***************')
        # self.writer = SummaryWriter(f'./logs/possion2d/DGNet')
        self.t = time.time()
        self.Lfbgs.step(self.loss_lfbgs)
        torch.save(self.model.state_dict(), f'./models/DGNet/{self.name}.pth')
        loss = self.loss_adam()
        best_loss = loss
        while loss > 1e-5:
            loss.backward()
            self.Adam.step()
            loss = self.loss_adam()
            if loss < best_loss:
                best_loss = loss
                torch.save(self.model.state_dict(), f'./models/DGNet/{self.name}.pth')
            if self.adamiter > self.maxiter:
                break
        self.adamiter = 0
        print(f'Finished training in {time.time()-self.t:.4f} seconds')
    def load(self):
        path = f'./models/DGNet/{self.name}.pth'
        if os.path.exists(path):
            print("Loading saved model...")
            model_dict = torch.load(path)
            self.model.load_state_dict(model_dict)
            return True
        else:
            print("No saved model found. Need to train")
            return False

p = Heat2d_dg(partition=0.1)
p.load()
p.loss()
p.train()
# Out:
# Loading saved model...
# *********** Started training ...... ***************
# LBFGS At iter: 100, loss_train:0.046971
# LBFGS At iter: 200, loss_train:0.046818
# LBFGS At iter: 300, loss_train:0.046666
# LBFGS At iter: 400, loss_train:0.046519
# LBFGS At iter: 500, loss_train:0.046369
# LBFGS At iter: 600, loss_train:0.046221
# LBFGS At iter: 700, loss_train:0.046053
# LBFGS At iter: 800, loss_train:0.045896
# LBFGS At iter: 900, loss_train:0.045741
# LBFGS At iter: 1000, loss_train:0.045578
# LBFGS At iter: 1100, loss_train:0.045414
# LBFGS At iter: 1200, loss_train:0.045254
# LBFGS At iter: 1300, loss_train:0.045105
# LBFGS At iter: 1400, loss_train:0.044959
# LBFGS At iter: 1500, loss_train:0.044822
# LBFGS At iter: 1600, loss_train:0.044707
# LBFGS At iter: 1700, loss_train:0.044588
# LBFGS At iter: 1800, loss_train:0.044450
# LBFGS At iter: 1900, loss_train:0.044323
# LBFGS At iter: 2000, loss_train:0.044206
# LBFGS At iter: 2100, loss_train:0.044079
# LBFGS At iter: 2200, loss_train:0.043921
# LBFGS At iter: 2300, loss_train:0.043757
# LBFGS At iter: 2400, loss_train:0.043624
# LBFGS At iter: 2500, loss_train:0.043486
# LBFGS At iter: 2600, loss_train:0.043351
# LBFGS At iter: 2700, loss_train:0.043214
# LBFGS At iter: 2800, loss_train:0.043073
# LBFGS At iter: 2900, loss_train:0.042919
# LBFGS At iter: 3000, loss_train:0.042775
# LBFGS At iter: 3100, loss_train:0.042652
# LBFGS At iter: 3200, loss_train:0.042516
# LBFGS At iter: 3300, loss_train:0.042384
# LBFGS At iter: 3400, loss_train:0.042262
# LBFGS At iter: 3500, loss_train:0.042148
# LBFGS At iter: 3600, loss_train:0.042023
# LBFGS At iter: 3700, loss_train:0.041906
# LBFGS At iter: 3800, loss_train:0.041787
# LBFGS At iter: 3900, loss_train:0.041674
# LBFGS At iter: 4000, loss_train:0.041545
# LBFGS At iter: 4100, loss_train:0.041422
# LBFGS At iter: 4200, loss_train:0.041301
# LBFGS At iter: 4300, loss_train:0.041195
# LBFGS At iter: 4400, loss_train:0.041085
# LBFGS At iter: 4500, loss_train:0.040961
# LBFGS At iter: 4600, loss_train:0.040838
# LBFGS At iter: 4700, loss_train:0.040724
# LBFGS At iter: 4800, loss_train:0.040619
# LBFGS At iter: 4900, loss_train:0.040513
# LBFGS At iter: 5000, loss_train:0.040413
# LBFGS At iter: 5100, loss_train:0.040301
# LBFGS At iter: 5200, loss_train:0.040193
# LBFGS At iter: 5300, loss_train:0.040065
# LBFGS At iter: 5400, loss_train:0.039958
# LBFGS At iter: 5500, loss_train:0.039859
# LBFGS At iter: 5600, loss_train:0.039741
# LBFGS At iter: 5700, loss_train:0.039640
# LBFGS At iter: 5800, loss_train:0.039546
# LBFGS At iter: 5900, loss_train:0.039457
# LBFGS At iter: 6000, loss_train:0.039370
# LBFGS At iter: 6100, loss_train:0.039284
# LBFGS At iter: 6200, loss_train:0.039193
# LBFGS At iter: 6300, loss_train:0.039103
# LBFGS At iter: 6400, loss_train:0.039004
# LBFGS At iter: 6500, loss_train:0.038912
# LBFGS At iter: 6600, loss_train:0.038822
# LBFGS At iter: 6700, loss_train:0.038721
# LBFGS At iter: 6800, loss_train:0.038625
# LBFGS At iter: 6900, loss_train:0.038542
# LBFGS At iter: 7000, loss_train:0.038457
# LBFGS At iter: 7100, loss_train:0.038362
# LBFGS At iter: 7200, loss_train:0.038266
# LBFGS At iter: 7300, loss_train:0.038164
# LBFGS At iter: 7400, loss_train:0.038066
# LBFGS At iter: 7500, loss_train:0.037953
# LBFGS At iter: 7600, loss_train:0.037856
# LBFGS At iter: 7700, loss_train:0.037765
# LBFGS At iter: 7800, loss_train:0.037670
# LBFGS At iter: 7900, loss_train:0.037585
# LBFGS At iter: 8000, loss_train:0.037503
# LBFGS At iter: 8100, loss_train:0.037424
# LBFGS At iter: 8200, loss_train:0.037334
# LBFGS At iter: 8300, loss_train:0.037248
# LBFGS At iter: 8400, loss_train:0.037165
# LBFGS At iter: 8500, loss_train:0.037089
# LBFGS At iter: 8600, loss_train:0.037010
# LBFGS At iter: 8700, loss_train:0.036923
# LBFGS At iter: 8800, loss_train:0.036836
# LBFGS At iter: 8900, loss_train:0.036752
# LBFGS At iter: 9000, loss_train:0.036676
# LBFGS At iter: 9100, loss_train:0.036597
# LBFGS At iter: 9200, loss_train:0.036501
# LBFGS At iter: 9300, loss_train:0.036410
# LBFGS At iter: 9400, loss_train:0.036320
# LBFGS At iter: 9500, loss_train:0.036238
# LBFGS At iter: 9600, loss_train:0.036153
# LBFGS At iter: 9700, loss_train:0.036070
# LBFGS At iter: 9800, loss_train:0.035993
# LBFGS At iter: 9900, loss_train:0.035914
# LBFGS At iter: 10000, loss_train:0.035830
# LBFGS At iter: 10100, loss_train:0.035738
# LBFGS At iter: 10200, loss_train:0.035644
# LBFGS At iter: 10300, loss_train:0.035560
# LBFGS At iter: 10400, loss_train:0.035473
# LBFGS At iter: 10500, loss_train:0.035377
# LBFGS At iter: 10600, loss_train:0.035285
# LBFGS At iter: 10700, loss_train:0.035192
# LBFGS At iter: 10800, loss_train:0.035099
# LBFGS At iter: 10900, loss_train:0.035014
# LBFGS At iter: 11000, loss_train:0.034930
# LBFGS At iter: 11100, loss_train:0.034836
# LBFGS At iter: 11200, loss_train:0.034746
# LBFGS At iter: 11300, loss_train:0.034657
# LBFGS At iter: 11400, loss_train:0.034571
# LBFGS At iter: 11500, loss_train:0.034493
# LBFGS At iter: 11600, loss_train:0.034418
# LBFGS At iter: 11700, loss_train:0.034342
# LBFGS At iter: 11800, loss_train:0.034259
# LBFGS At iter: 11900, loss_train:0.034181
# LBFGS At iter: 12000, loss_train:0.034107
# LBFGS At iter: 12100, loss_train:0.034029
# LBFGS At iter: 12200, loss_train:0.033948
# LBFGS At iter: 12300, loss_train:0.033868
# LBFGS At iter: 12400, loss_train:0.033791
# LBFGS At iter: 12500, loss_train:0.033717
# LBFGS At iter: 12600, loss_train:0.033637
# LBFGS At iter: 12700, loss_train:0.033566
# LBFGS At iter: 12800, loss_train:0.033493
# LBFGS At iter: 12900, loss_train:0.033424
# LBFGS At iter: 13000, loss_train:0.033352
# LBFGS At iter: 13100, loss_train:0.033265
# LBFGS At iter: 13200, loss_train:0.033188
# LBFGS At iter: 13300, loss_train:0.033116
# LBFGS At iter: 13400, loss_train:0.033040
# LBFGS At iter: 13500, loss_train:0.032965
# LBFGS At iter: 13600, loss_train:0.032888
# LBFGS At iter: 13700, loss_train:0.032807
# LBFGS At iter: 13800, loss_train:0.032726
# LBFGS At iter: 13900, loss_train:0.032653
# LBFGS At iter: 14000, loss_train:0.032571
# LBFGS At iter: 14100, loss_train:0.032488
# LBFGS At iter: 14200, loss_train:0.032418
# LBFGS At iter: 14300, loss_train:0.032353
# LBFGS At iter: 14400, loss_train:0.032282
# LBFGS At iter: 14500, loss_train:0.032206
# LBFGS At iter: 14600, loss_train:0.032138
# LBFGS At iter: 14700, loss_train:0.032070
# LBFGS At iter: 14800, loss_train:0.032003
# LBFGS At iter: 14900, loss_train:0.031933
# LBFGS At iter: 15000, loss_train:0.031860
# LBFGS At iter: 15100, loss_train:0.031787
# LBFGS At iter: 15200, loss_train:0.031720
# LBFGS At iter: 15300, loss_train:0.031649
# LBFGS At iter: 15400, loss_train:0.031583
# LBFGS At iter: 15500, loss_train:0.031510
# LBFGS At iter: 15600, loss_train:0.031448
# LBFGS At iter: 15700, loss_train:0.031388
# LBFGS At iter: 15800, loss_train:0.031313
# LBFGS At iter: 15900, loss_train:0.031250
# LBFGS At iter: 16000, loss_train:0.031181
# LBFGS At iter: 16100, loss_train:0.031102
# LBFGS At iter: 16200, loss_train:0.031023
# LBFGS At iter: 16300, loss_train:0.030953
# LBFGS At iter: 16400, loss_train:0.030874
# LBFGS At iter: 16500, loss_train:0.030794
# LBFGS At iter: 16600, loss_train:0.030718
# LBFGS At iter: 16700, loss_train:0.030649
# LBFGS At iter: 16800, loss_train:0.030588
# LBFGS At iter: 16900, loss_train:0.030514
# LBFGS At iter: 17000, loss_train:0.030441
# LBFGS At iter: 17100, loss_train:0.030373
# LBFGS At iter: 17200, loss_train:0.030305
# LBFGS At iter: 17300, loss_train:0.030234
# LBFGS At iter: 17400, loss_train:0.030161
# LBFGS At iter: 17500, loss_train:0.030104
# LBFGS At iter: 17600, loss_train:0.030044
# LBFGS At iter: 17700, loss_train:0.029986
# LBFGS At iter: 17800, loss_train:0.029928
# LBFGS At iter: 17900, loss_train:0.029871
# LBFGS At iter: 18000, loss_train:0.029811
# LBFGS At iter: 18100, loss_train:0.029750
# LBFGS At iter: 18200, loss_train:0.029687
# LBFGS At iter: 18300, loss_train:0.029626
# LBFGS At iter: 18400, loss_train:0.029562
# LBFGS At iter: 18500, loss_train:0.029503
# LBFGS At iter: 18600, loss_train:0.029443
# LBFGS At iter: 18700, loss_train:0.029386
# LBFGS At iter: 18800, loss_train:0.029326
# LBFGS At iter: 18900, loss_train:0.029263
# LBFGS At iter: 19000, loss_train:0.029209
# LBFGS At iter: 19100, loss_train:0.029156
# LBFGS At iter: 19200, loss_train:0.029108
# LBFGS At iter: 19300, loss_train:0.029047
# LBFGS At iter: 19400, loss_train:0.028984
# LBFGS At iter: 19500, loss_train:0.028925
# LBFGS At iter: 19600, loss_train:0.028854
# LBFGS At iter: 19700, loss_train:0.028792
# LBFGS At iter: 19800, loss_train:0.028732
# LBFGS At iter: 19900, loss_train:0.028666
# LBFGS At iter: 20000, loss_train:0.028596
# LBFGS At iter: 20100, loss_train:0.028532
# LBFGS At iter: 20200, loss_train:0.028471
# LBFGS At iter: 20300, loss_train:0.028420
# LBFGS At iter: 20400, loss_train:0.028360
# LBFGS At iter: 20500, loss_train:0.028295
# LBFGS At iter: 20600, loss_train:0.028234
# LBFGS At iter: 20700, loss_train:0.028172
# LBFGS At iter: 20800, loss_train:0.028114
# LBFGS At iter: 20900, loss_train:0.028059
# LBFGS At iter: 21000, loss_train:0.028001
# LBFGS At iter: 21100, loss_train:0.027951
# LBFGS At iter: 21200, loss_train:0.027897
# LBFGS At iter: 21300, loss_train:0.027841
# LBFGS At iter: 21400, loss_train:0.027781
# LBFGS At iter: 21500, loss_train:0.027729
# LBFGS At iter: 21600, loss_train:0.027676
# LBFGS At iter: 21700, loss_train:0.027623
# LBFGS At iter: 21800, loss_train:0.027577
# LBFGS At iter: 21900, loss_train:0.027522
# LBFGS At iter: 22000, loss_train:0.027467
# LBFGS At iter: 22100, loss_train:0.027416
# LBFGS At iter: 22200, loss_train:0.027362
# LBFGS At iter: 22300, loss_train:0.027304
# LBFGS At iter: 22400, loss_train:0.027251
# LBFGS At iter: 22500, loss_train:0.027206
# LBFGS At iter: 22600, loss_train:0.027161
# LBFGS At iter: 22700, loss_train:0.027122
# LBFGS At iter: 22800, loss_train:0.027073
# LBFGS At iter: 22900, loss_train:0.027022
# LBFGS At iter: 23000, loss_train:0.026967
# LBFGS At iter: 23100, loss_train:0.026912
# LBFGS At iter: 23200, loss_train:0.026861
# LBFGS At iter: 23300, loss_train:0.026813
# LBFGS At iter: 23400, loss_train:0.026766
# LBFGS At iter: 23500, loss_train:0.026718
# LBFGS At iter: 23600, loss_train:0.026670
# LBFGS At iter: 23700, loss_train:0.026623
# LBFGS At iter: 23800, loss_train:0.026565
# LBFGS At iter: 23900, loss_train:0.026519
# LBFGS At iter: 24000, loss_train:0.026472
# LBFGS At iter: 24100, loss_train:0.026431
# LBFGS At iter: 24200, loss_train:0.026387
# LBFGS At iter: 24300, loss_train:0.026343
# LBFGS At iter: 24400, loss_train:0.026298
# LBFGS At iter: 24500, loss_train:0.026255
# LBFGS At iter: 24600, loss_train:0.026210
# LBFGS At iter: 24700, loss_train:0.026163
# LBFGS At iter: 24800, loss_train:0.026114
# LBFGS At iter: 24900, loss_train:0.026069
# LBFGS At iter: 25000, loss_train:0.026020
# LBFGS At iter: 25100, loss_train:0.025971
# LBFGS At iter: 25200, loss_train:0.025924
# LBFGS At iter: 25300, loss_train:0.025882
# LBFGS At iter: 25400, loss_train:0.025846
# LBFGS At iter: 25500, loss_train:0.025804
# LBFGS At iter: 25600, loss_train:0.025763
# LBFGS At iter: 25700, loss_train:0.025722
# LBFGS At iter: 25800, loss_train:0.025677
# LBFGS At iter: 25900, loss_train:0.025631
# LBFGS At iter: 26000, loss_train:0.025579
# LBFGS At iter: 26100, loss_train:0.025537
# LBFGS At iter: 26200, loss_train:0.025492
# LBFGS At iter: 26300, loss_train:0.025446
# LBFGS At iter: 26400, loss_train:0.025396
# LBFGS At iter: 26500, loss_train:0.025347
# LBFGS At iter: 26600, loss_train:0.025305
# LBFGS At iter: 26700, loss_train:0.025262
# LBFGS At iter: 26800, loss_train:0.025218
# LBFGS At iter: 26900, loss_train:0.025177
# LBFGS At iter: 27000, loss_train:0.025130
# LBFGS At iter: 27100, loss_train:0.025085
# LBFGS At iter: 27200, loss_train:0.025044
# LBFGS At iter: 27300, loss_train:0.025006
# LBFGS At iter: 27400, loss_train:0.024967
# LBFGS At iter: 27500, loss_train:0.024933
# LBFGS At iter: 27600, loss_train:0.024895
# LBFGS At iter: 27700, loss_train:0.024852
# LBFGS At iter: 27800, loss_train:0.024809
# LBFGS At iter: 27900, loss_train:0.024767
# LBFGS At iter: 28000, loss_train:0.024725
# LBFGS At iter: 28100, loss_train:0.024687
# LBFGS At iter: 28200, loss_train:0.024646
# LBFGS At iter: 28300, loss_train:0.024608
# LBFGS At iter: 28400, loss_train:0.024567
# LBFGS At iter: 28500, loss_train:0.024527
# LBFGS At iter: 28600, loss_train:0.024492
# LBFGS At iter: 28700, loss_train:0.024452
# LBFGS At iter: 28800, loss_train:0.024414
# LBFGS At iter: 28900, loss_train:0.024372
# LBFGS At iter: 29000, loss_train:0.024326
# LBFGS At iter: 29100, loss_train:0.024283
# LBFGS At iter: 29200, loss_train:0.024243
# LBFGS At iter: 29300, loss_train:0.024198
# LBFGS At iter: 29400, loss_train:0.024156
# LBFGS At iter: 29500, loss_train:0.024111
# LBFGS At iter: 29600, loss_train:0.024070
# LBFGS At iter: 29700, loss_train:0.024035
# LBFGS At iter: 29800, loss_train:0.023998
# LBFGS At iter: 29900, loss_train:0.023958
# LBFGS At iter: 30000, loss_train:0.023918
# LBFGS At iter: 30100, loss_train:0.023877
# LBFGS At iter: 30200, loss_train:0.023834
# LBFGS At iter: 30300, loss_train:0.023795
# LBFGS At iter: 30400, loss_train:0.023752
# LBFGS At iter: 30500, loss_train:0.023704
# LBFGS At iter: 30600, loss_train:0.023659
# LBFGS At iter: 30700, loss_train:0.023610
# LBFGS At iter: 30800, loss_train:0.023568
# LBFGS At iter: 30900, loss_train:0.023529
# LBFGS At iter: 31000, loss_train:0.023487
# LBFGS At iter: 31100, loss_train:0.023450
# LBFGS At iter: 31200, loss_train:0.023410
# LBFGS At iter: 31300, loss_train:0.023373
# LBFGS At iter: 31400, loss_train:0.023340
# LBFGS At iter: 31500, loss_train:0.023304
# LBFGS At iter: 31600, loss_train:0.023269
# LBFGS At iter: 31700, loss_train:0.023230
# LBFGS At iter: 31800, loss_train:0.023193
# LBFGS At iter: 31900, loss_train:0.023152
# LBFGS At iter: 32000, loss_train:0.023105
# LBFGS At iter: 32100, loss_train:0.023064
# LBFGS At iter: 32200, loss_train:0.023023
# LBFGS At iter: 32300, loss_train:0.022984
# LBFGS At iter: 32400, loss_train:0.022946
# LBFGS At iter: 32500, loss_train:0.022909
# LBFGS At iter: 32600, loss_train:0.022871
# LBFGS At iter: 32700, loss_train:0.022826
# LBFGS At iter: 32800, loss_train:0.022786
# LBFGS At iter: 32900, loss_train:0.022750
# LBFGS At iter: 33000, loss_train:0.022714
# LBFGS At iter: 33100, loss_train:0.022680
# LBFGS At iter: 33200, loss_train:0.022647
# LBFGS At iter: 33300, loss_train:0.022610
# LBFGS At iter: 33400, loss_train:0.022580
# LBFGS At iter: 33500, loss_train:0.022549
# LBFGS At iter: 33600, loss_train:0.022517
# LBFGS At iter: 33700, loss_train:0.022487
# LBFGS At iter: 33800, loss_train:0.022456
# LBFGS At iter: 33900, loss_train:0.022425
# LBFGS At iter: 34000, loss_train:0.022389
# LBFGS At iter: 34100, loss_train:0.022355
# LBFGS At iter: 34200, loss_train:0.022321
# LBFGS At iter: 34300, loss_train:0.022289
# LBFGS At iter: 34400, loss_train:0.022258
# LBFGS At iter: 34500, loss_train:0.022227
# LBFGS At iter: 34600, loss_train:0.022196
# LBFGS At iter: 34700, loss_train:0.022163
# LBFGS At iter: 34800, loss_train:0.022128
# LBFGS At iter: 34900, loss_train:0.022093
# LBFGS At iter: 35000, loss_train:0.022059
# LBFGS At iter: 35100, loss_train:0.022025
# LBFGS At iter: 35200, loss_train:0.021991
# LBFGS At iter: 35300, loss_train:0.021963
# LBFGS At iter: 35400, loss_train:0.021929
# LBFGS At iter: 35500, loss_train:0.021896
# LBFGS At iter: 35600, loss_train:0.021862
# LBFGS At iter: 35700, loss_train:0.021829
# LBFGS At iter: 35800, loss_train:0.021792
# LBFGS At iter: 35900, loss_train:0.021750
# LBFGS At iter: 36000, loss_train:0.021712
# LBFGS At iter: 36100, loss_train:0.021674
# LBFGS At iter: 36200, loss_train:0.021634
# LBFGS At iter: 36300, loss_train:0.021594
# LBFGS At iter: 36400, loss_train:0.021552
# LBFGS At iter: 36500, loss_train:0.021511
# LBFGS At iter: 36600, loss_train:0.021470
# LBFGS At iter: 36700, loss_train:0.021431
# LBFGS At iter: 36800, loss_train:0.021389
# LBFGS At iter: 36900, loss_train:0.021347
# LBFGS At iter: 37000, loss_train:0.021299
# LBFGS At iter: 37100, loss_train:0.021254
# LBFGS At iter: 37200, loss_train:0.021206
# LBFGS At iter: 37300, loss_train:0.021166
# LBFGS At iter: 37400, loss_train:0.021129
# LBFGS At iter: 37500, loss_train:0.021091
# LBFGS At iter: 37600, loss_train:0.021052
# LBFGS At iter: 37700, loss_train:0.021017
# LBFGS At iter: 37800, loss_train:0.020980
# LBFGS At iter: 37900, loss_train:0.020945
# LBFGS At iter: 38000, loss_train:0.020911
# LBFGS At iter: 38100, loss_train:0.020879
# LBFGS At iter: 38200, loss_train:0.020849
# LBFGS At iter: 38300, loss_train:0.020813
# LBFGS At iter: 38400, loss_train:0.020776
# LBFGS At iter: 38500, loss_train:0.020742
# LBFGS At iter: 38600, loss_train:0.020710
# LBFGS At iter: 38700, loss_train:0.020679
# LBFGS At iter: 38800, loss_train:0.020651
# LBFGS At iter: 38900, loss_train:0.020619
# LBFGS At iter: 39000, loss_train:0.020590
# LBFGS At iter: 39100, loss_train:0.020564
# LBFGS At iter: 39200, loss_train:0.020539
# LBFGS At iter: 39300, loss_train:0.020509
# LBFGS At iter: 39400, loss_train:0.020481
# LBFGS At iter: 39500, loss_train:0.020452
# LBFGS At iter: 39600, loss_train:0.020427
# LBFGS At iter: 39700, loss_train:0.020400
# LBFGS At iter: 39800, loss_train:0.020376
# LBFGS At iter: 39900, loss_train:0.020350
# LBFGS At iter: 40000, loss_train:0.020321
# LBFGS At iter: 40100, loss_train:0.020299
# LBFGS At iter: 40200, loss_train:0.020272
# LBFGS At iter: 40300, loss_train:0.020244
# LBFGS At iter: 40400, loss_train:0.020220
# LBFGS At iter: 40500, loss_train:0.020192
# LBFGS At iter: 40600, loss_train:0.020163
# LBFGS At iter: 40700, loss_train:0.020136
# LBFGS At iter: 40800, loss_train:0.020105
# LBFGS At iter: 40900, loss_train:0.020079
# LBFGS At iter: 41000, loss_train:0.020055
# LBFGS At iter: 41100, loss_train:0.020030
# LBFGS At iter: 41200, loss_train:0.020009
# LBFGS At iter: 41300, loss_train:0.019988
# LBFGS At iter: 41400, loss_train:0.019965
# LBFGS At iter: 41500, loss_train:0.019943
# LBFGS At iter: 41600, loss_train:0.019922
# LBFGS At iter: 41700, loss_train:0.019900
# LBFGS At iter: 41800, loss_train:0.019876
# LBFGS At iter: 41900, loss_train:0.019854
# LBFGS At iter: 42000, loss_train:0.019832
# LBFGS At iter: 42100, loss_train:0.019809
# LBFGS At iter: 42200, loss_train:0.019783
# LBFGS At iter: 42300, loss_train:0.019756
# LBFGS At iter: 42400, loss_train:0.019736
# LBFGS At iter: 42500, loss_train:0.019709
# LBFGS At iter: 42600, loss_train:0.019684
# LBFGS At iter: 42700, loss_train:0.019656
# LBFGS At iter: 42800, loss_train:0.019631
# LBFGS At iter: 42900, loss_train:0.019608
# LBFGS At iter: 43000, loss_train:0.019587
# LBFGS At iter: 43100, loss_train:0.019564
# LBFGS At iter: 43200, loss_train:0.019541
# LBFGS At iter: 43300, loss_train:0.019523
# LBFGS At iter: 43400, loss_train:0.019504
# LBFGS At iter: 43500, loss_train:0.019486
# LBFGS At iter: 43600, loss_train:0.019467
# LBFGS At iter: 43700, loss_train:0.019444
# LBFGS At iter: 43800, loss_train:0.019420
# LBFGS At iter: 43900, loss_train:0.019398
# LBFGS At iter: 44000, loss_train:0.019378
# LBFGS At iter: 44100, loss_train:0.019355
# LBFGS At iter: 44200, loss_train:0.019333
# LBFGS At iter: 44300, loss_train:0.019308
# LBFGS At iter: 44400, loss_train:0.019283
# LBFGS At iter: 44500, loss_train:0.019259
# LBFGS At iter: 44600, loss_train:0.019236
# LBFGS At iter: 44700, loss_train:0.019215
# LBFGS At iter: 44800, loss_train:0.019193
# LBFGS At iter: 44900, loss_train:0.019171
# LBFGS At iter: 45000, loss_train:0.019149
# LBFGS At iter: 45100, loss_train:0.019121
# LBFGS At iter: 45200, loss_train:0.019094
# LBFGS At iter: 45300, loss_train:0.019070
# LBFGS At iter: 45400, loss_train:0.019046
# LBFGS At iter: 45500, loss_train:0.019020
# LBFGS At iter: 45600, loss_train:0.018990
# LBFGS At iter: 45700, loss_train:0.018962
# LBFGS At iter: 45800, loss_train:0.018937
# LBFGS At iter: 45900, loss_train:0.018908
# LBFGS At iter: 46000, loss_train:0.018882
# LBFGS At iter: 46100, loss_train:0.018855
# LBFGS At iter: 46200, loss_train:0.018828
# LBFGS At iter: 46300, loss_train:0.018799
# LBFGS At iter: 46400, loss_train:0.018769
# LBFGS At iter: 46500, loss_train:0.018740
# LBFGS At iter: 46600, loss_train:0.018714
# LBFGS At iter: 46700, loss_train:0.018683
# LBFGS At iter: 46800, loss_train:0.018658
# LBFGS At iter: 46900, loss_train:0.018634
# LBFGS At iter: 47000, loss_train:0.018605
# LBFGS At iter: 47100, loss_train:0.018580
# LBFGS At iter: 47200, loss_train:0.018552
# LBFGS At iter: 47300, loss_train:0.018526
# LBFGS At iter: 47400, loss_train:0.018500
# LBFGS At iter: 47500, loss_train:0.018467
# LBFGS At iter: 47600, loss_train:0.018437
# LBFGS At iter: 47700, loss_train:0.018412
# LBFGS At iter: 47800, loss_train:0.018386
# LBFGS At iter: 47900, loss_train:0.018360
# LBFGS At iter: 48000, loss_train:0.018332
# LBFGS At iter: 48100, loss_train:0.018303
# LBFGS At iter: 48200, loss_train:0.018276
# LBFGS At iter: 48300, loss_train:0.018244
# LBFGS At iter: 48400, loss_train:0.018212
# LBFGS At iter: 48500, loss_train:0.018180
# LBFGS At iter: 48600, loss_train:0.018151
# LBFGS At iter: 48700, loss_train:0.018118
# LBFGS At iter: 48800, loss_train:0.018086
# LBFGS At iter: 48900, loss_train:0.018057
# LBFGS At iter: 49000, loss_train:0.018031
# LBFGS At iter: 49100, loss_train:0.018008
# LBFGS At iter: 49200, loss_train:0.017981
# LBFGS At iter: 49300, loss_train:0.017958
# LBFGS At iter: 49400, loss_train:0.017935
# LBFGS At iter: 49500, loss_train:0.017914
# LBFGS At iter: 49600, loss_train:0.017888
# LBFGS At iter: 49700, loss_train:0.017862
# LBFGS At iter: 49800, loss_train:0.017838
# LBFGS At iter: 49900, loss_train:0.017815
# LBFGS At iter: 50000, loss_train:0.017793
# Adam At iter: 100, loss_train:0.020699
# Adam At iter: 200, loss_train:0.018226
# Adam At iter: 300, loss_train:0.019147
# Adam At iter: 400, loss_train:0.017891
# Adam At iter: 500, loss_train:0.057835
# Adam At iter: 600, loss_train:0.017819
# Adam At iter: 700, loss_train:0.068574
# Adam At iter: 800, loss_train:0.400218
# Adam At iter: 900, loss_train:0.128759
# Adam At iter: 1000, loss_train:0.080726
# Adam At iter: 1100, loss_train:0.979578
# Adam At iter: 1200, loss_train:0.023177
# Adam At iter: 1300, loss_train:0.037180
# Adam At iter: 1400, loss_train:0.064074
# Adam At iter: 1500, loss_train:0.029989
# Adam At iter: 1600, loss_train:0.089531
# Adam At iter: 1700, loss_train:0.494080
# Adam At iter: 1800, loss_train:0.020669
# Adam At iter: 1900, loss_train:0.069324
# Adam At iter: 2000, loss_train:0.018710
# Adam At iter: 2100, loss_train:0.046259
# Adam At iter: 2200, loss_train:0.369636
# Adam At iter: 2300, loss_train:0.102102
# Adam At iter: 2400, loss_train:0.455162
# Adam At iter: 2500, loss_train:0.018377
# Adam At iter: 2600, loss_train:0.020858
# Adam At iter: 2700, loss_train:0.110762
# Adam At iter: 2800, loss_train:0.109140
# Adam At iter: 2900, loss_train:0.039962
# Adam At iter: 3000, loss_train:0.030931
# Adam At iter: 3100, loss_train:0.023428
# Adam At iter: 3200, loss_train:0.026300
# Adam At iter: 3300, loss_train:0.017855
# Adam At iter: 3400, loss_train:0.148220
# Adam At iter: 3500, loss_train:1.035430
# Adam At iter: 3600, loss_train:0.266375
# Adam At iter: 3700, loss_train:0.021400
# Adam At iter: 3800, loss_train:0.019231
# Adam At iter: 3900, loss_train:0.017909
# Adam At iter: 4000, loss_train:0.020992
# Adam At iter: 4100, loss_train:0.030857
# Adam At iter: 4200, loss_train:0.202884
# Adam At iter: 4300, loss_train:0.122332
# Adam At iter: 4400, loss_train:0.025150
# Adam At iter: 4500, loss_train:0.028162
# Adam At iter: 4600, loss_train:0.032264
# Adam At iter: 4700, loss_train:0.101871
# Adam At iter: 4800, loss_train:0.023542
# Adam At iter: 4900, loss_train:0.020302
# Adam At iter: 5000, loss_train:0.952184
# Adam At iter: 5100, loss_train:0.268571
# Adam At iter: 5200, loss_train:0.024967
# Adam At iter: 5300, loss_train:0.159341
# Adam At iter: 5400, loss_train:0.022446
# Adam At iter: 5500, loss_train:0.171452
# Adam At iter: 5600, loss_train:0.063980
# Adam At iter: 5700, loss_train:0.080012
# Adam At iter: 5800, loss_train:0.057767
# Adam At iter: 5900, loss_train:0.029997
# Adam At iter: 6000, loss_train:0.064398
# Adam At iter: 6100, loss_train:0.555212
# Adam At iter: 6200, loss_train:0.332740
# Adam At iter: 6300, loss_train:0.424974
# Adam At iter: 6400, loss_train:0.215726
# Adam At iter: 6500, loss_train:0.018420
# Adam At iter: 6600, loss_train:0.018554
# Adam At iter: 6700, loss_train:0.019476
# Adam At iter: 6800, loss_train:0.024623
# Adam At iter: 6900, loss_train:0.020619
# Adam At iter: 7000, loss_train:0.020234
# Adam At iter: 7100, loss_train:0.020141
# Adam At iter: 7200, loss_train:0.681806
# Adam At iter: 7300, loss_train:0.205921
# Adam At iter: 7400, loss_train:0.631736
# Adam At iter: 7500, loss_train:0.049843
# Adam At iter: 7600, loss_train:0.028270
# Adam At iter: 7700, loss_train:0.040316
# Adam At iter: 7800, loss_train:0.036782
# Adam At iter: 7900, loss_train:0.285392
# Adam At iter: 8000, loss_train:0.116054
# Adam At iter: 8100, loss_train:0.058726
# Adam At iter: 8200, loss_train:0.018845
# Adam At iter: 8300, loss_train:0.023028
# Adam At iter: 8400, loss_train:0.020324
# Adam At iter: 8500, loss_train:0.017765
# Adam At iter: 8600, loss_train:0.047895
# Adam At iter: 8700, loss_train:0.078387
# Adam At iter: 8800, loss_train:0.932245
# Adam At iter: 8900, loss_train:0.094044
# Adam At iter: 9000, loss_train:0.201142
# Adam At iter: 9100, loss_train:0.071929
# Adam At iter: 9200, loss_train:0.019227
# Adam At iter: 9300, loss_train:0.019997
# Adam At iter: 9400, loss_train:0.026017
# Adam At iter: 9500, loss_train:0.033372
# Adam At iter: 9600, loss_train:0.020194
# Adam At iter: 9700, loss_train:0.132101
# Adam At iter: 9800, loss_train:0.035906
# Adam At iter: 9900, loss_train:0.031291
# Adam At iter: 10000, loss_train:0.023292
# Finished training in 616.6292 seconds

# %%
# problem = Heat2d_dg(order=2, partition=0.1)
# model = DGNet(num_modules=problem.Nelt, input_size=3, hidden_size=50, 
#                             output_size=1, num_layers=2, act='tanh').to(device).to(problem.torch_type)
# model.load_state_dict(torch.load(f'./models/DGNet/{problem.name}.pth'))
# x = problem.Mesh.clone().detach().requires_grad_(True).to(device)
# y = model(x) # [Elements, Time, Points, 1]

# x = x[:, 0, :, :2].reshape(-1, 2).detach().cpu().numpy()
# y = y[:, 9, :, 0].detach().cpu().numpy()
# # assert np.all(np.isfinite(x)) and np.all(np.isfinite(y))
# f = problem.f
# plt.tricontourf(x[:, 0], x[:, 1], y.flatten(), cmap='jet', levels=100)
# plt.colorbar()

# %%
from matplotlib.tri import Triangulation
from matplotlib.animation import FuncAnimation
from IPython.display import HTML

problem = Heat2d_dg(order=2, partition=0.1)
model = DGNet(num_modules=problem.Nelt, input_size=3, hidden_size=50, output_size=1, num_layers=2, act='tanh').to(device).to(problem.torch_type)
model.load_state_dict(torch.load(f'./models/DGNet/{problem.name}.pth'))
# 1. 预处理网格与解
Nt = 100
t = torch.linspace(0, 1.0, Nt + 1).to(device)
x = problem.xMesh.clone().detach().to(device)
Mesh = torch.cat((x[:, None, ...].expand(-1, Nt + 1, -1, -1), t[None, :, None, None].expand(x.shape[0], -1, x.shape[1], -1)), dim=-1).to(device)
y = model(Mesh)  # shape: [Elements, Time, Points, 1]

# 抽取静态网格坐标 (time-independent)
x_plot = Mesh[:, 0, :, :2].reshape(-1, 2).detach().cpu().numpy()
tri = Triangulation(x_plot[:, 0], x_plot[:, 1])

# 抽取所有时间步解
y_all = y.detach().cpu().numpy()   # shape: [Elements, Time, Points, 1]
y_all = y_all[:, :, :, 0].transpose(1, 0, 2).reshape(Nt + 1, -1)  # shape: [Time, (Elements * Points)]

# 设置统一颜色范围
vmin = y_all.min()
vmax = y_all.max()

# 2. 创建动画
fig, ax = plt.subplots(figsize=(6, 5))
cmap = plt.get_cmap('jet')
contour = ax.tricontourf(tri, y_all[0], cmap=cmap, levels=100, vmin=vmin, vmax=vmax)
cb = fig.colorbar(contour)
title = ax.set_title("Time step: 0")

def update(i):
    ax.clear()
    contour = ax.tricontourf(tri, y_all[i], cmap=cmap, levels=100, vmin=vmin, vmax=vmax)
    title = ax.set_title(f"Time step: {i}")
    return contour.collections + [title]

ani = FuncAnimation(fig, update, frames=Nt + 1, interval=200, blit=False)
plt.close(fig)  # 防止重复静态图输出
HTML(ani.to_jshtml())
# Out:
# /root/anaconda3/lib/python3.9/site-packages/torch/nn/functional.py:1949: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img79f9546d49664df2b41292ea84e4cf8e">
#   <div class="anim-controls">
#     <input id="_anim_slider79f9546d49664df2b41292ea84e4cf8e" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim79f9546d49664df2b41292ea84e4cf8e.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim79f9546d49664df2b41292ea84e4cf8e.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim79f9546d49664df2b41292ea84e4cf8e.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim79f9546d49664df2b41292ea84e4cf8e.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim79f9546d49664df2b41292ea84e4cf8e.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim79f9546d49664df2b41292ea84e4cf8e.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim79f9546d49664df2b41292ea84e4cf8e.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim79f9546d49664df2b41292ea84e4cf8e.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim79f9546d49664df2b41292ea84e4cf8e.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim79f9546d49664df2b41292ea84e4cf8e.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select79f9546d49664df2b41292ea84e4cf8e"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_79f9546d49664df2b41292ea84e4cf8e"
#              >
#       <label for="_anim_radio1_79f9546d49664df2b41292ea84e4cf8e">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_79f9546d49664df2b41292ea84e4cf8e"
#              checked>
#       <label for="_anim_radio2_79f9546d49664df2b41292ea84e4cf8e">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_79f9546d49664df2b41292ea84e4cf8e"
#              >
#       <label for="_anim_radio3_79f9546d49664df2b41292ea84e4cf8e">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img79f9546d49664df2b41292ea84e4cf8e";
#     var slider_id = "_anim_slider79f9546d49664df2b41292ea84e4cf8e";
#     var loop_select_id = "_anim_loop_select79f9546d49664df2b41292ea84e4cf8e";
#     var frames = new Array(101);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjUuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/YYfK9AAAACXBIWXMAAAsT\
# AAALEwEAmpwY

# %%
ani.save('./pics/heat2d.gif', writer='pillow', fps=20)

# %%
import torch
import matplotlib.pyplot as plt
from matplotlib.tri import Triangulation
import matplotlib.ticker as mticker
from mpl_toolkits.axes_grid1 import make_axes_locatable

# 加载模型与数据
problem = Heat2d_dg(order=2, partition=0.1)
model = DGNet(
    num_modules=problem.Nelt,
    input_size=3,
    hidden_size=50,
    output_size=1,
    num_layers=2,
    act='tanh'
).to(device).to(problem.torch_type)
model.load_state_dict(torch.load(f'./models/DGNet/{problem.name}.pth'))

# 时间设置
Nt = 4
t = torch.linspace(0, 1.0, Nt + 1).to(device)
x = problem.xMesh.clone().detach().to(device)

# 构建 mesh: [Ne, Nt+1, Np, 3]
Mesh = torch.cat(
    (
        x[:, None, ...].expand(-1, Nt + 1, -1, -1),
        t[None, :, None, None].expand(x.shape[0], -1, x.shape[1], 1)
    ),
    dim=-1
).to(device)

# 预测值与精确解
y_pred = model(Mesh)
y_exact = problem.exact_u(Mesh[..., [0]], Mesh[..., [1]], Mesh[..., [2]])

# 网格点：用 t=0 的坐标作为绘图坐标
x_plot = Mesh[:, 0, :, :2].reshape(-1, 2).cpu().numpy()
tri = Triangulation(x_plot[:, 0], x_plot[:, 1])

# reshape 成 [Nt+1, Ne*Np]
y_all = y_pred.detach().cpu().numpy()[..., 0].transpose(1, 0, 2).reshape(Nt + 1, -1)
y_exact_all = y_exact.detach().cpu().numpy()[..., 0].transpose(1, 0, 2).reshape(Nt + 1, -1)
error_all = abs(y_all - y_exact_all)

# 统一色标
vmin = y_all.min()
vmax = y_all.max()
err_max = error_all.max()

# 开始画图
fig, axes = plt.subplots(2, Nt + 1, figsize=(15, 6), constrained_layout=True)
cmap = plt.get_cmap('jet')

# 存储最后一列用于 colorbar 定位
tpc1 = None
tpc2 = None

for i in range(Nt + 1):
    # 第一行：预测值
    ax1 = axes[0, i]
    tpc1 = ax1.tricontourf(tri, y_all[i], cmap=cmap, levels=100, vmin=vmin, vmax=vmax)
    ax1.set_title(f"Solution at t = {t[i].item():.2f} s")
    ax1.set_aspect('equal')
    ax1.set_xticks([])
    ax1.set_yticks([])

    # 第二行：误差图
    ax2 = axes[1, i]
    tpc2 = ax2.tricontourf(tri, error_all[i], cmap='jet', levels=100, vmin=0.0, vmax=err_max)
    ax2.set_title(f"Error at t = {t[i].item():.2f} s")
    ax2.set_aspect('equal')
    ax2.set_xticks([])
    ax2.set_yticks([])

# Colorbar 格式器（科学计数法）
formatter = mticker.ScalarFormatter(useMathText=True)
formatter.set_powerlimits((-1, 0))

# 第一行 colorbar：预测值
divider1 = make_axes_locatable(axes[0, -1])
cax1 = divider1.append_axes("right", size="5%", pad=0.05)
cb1 = plt.colorbar(tpc1, cax=cax1, format=formatter)
cb1.set_label(r'$u(x, y, t)$', fontsize=12)
cb1.ax.tick_params(labelsize=10)
cb1.ax.yaxis.get_offset_text().set_fontsize(10)

# 第二行 colorbar：误差
divider2 = make_axes_locatable(axes[1, -1])
cax2 = divider2.append_axes("right", size="5%", pad=0.05)
cb2 = plt.colorbar(tpc2, cax=cax2, format=formatter)
cb2.set_label(r'$|\hat{u}(x, y, t) - u(x, y, t)|$', fontsize=12)
cb2.ax.tick_params(labelsize=10)
cb2.ax.yaxis.get_offset_text().set_fontsize(10)

# 显示并保存
plt.tight_layout()  # 触发布局更新（无论你用了 constrained_layout 还是 tight_layout）
plt.savefig('./pics/2dHeatmap.pdf', bbox_inches='tight')
plt.show()
# Out:
# /root/anaconda3/lib/python3.9/site-packages/torch/nn/functional.py:1949: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# /tmp/ipykernel_1627/1424930027.py:97: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.
#   plt.tight_layout()  # 触发布局更新（无论你用了 constrained_layout 还是 tight_layout）
